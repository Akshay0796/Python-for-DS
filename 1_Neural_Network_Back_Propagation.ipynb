# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshay0796/Python-for-DS/blob/main/1_Neural_Network_Back_Propagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
# !pip install keras

# %%
# Create your first MLP in Keras
from keras.models import Sequential
from keras.layers import Dense
import numpy

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load pima indians dataset
dataset = numpy.loadtxt("/content/pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
# create model
model = Sequential()
model.add(Dense(12, input_dim=8,  activation='relu'))
model.add(Dense(8,  activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=250, batch_size=20)
# Out:
# Epoch 1/250
# 26/26 [==============================] - 14s 18ms/step - loss: 1.8750 - accuracy: 0.3786 - val_loss: 1.2305 - val_accuracy: 0.4803
# Epoch 2/250
# 26/26 [==============================] - 0s 2ms/step - loss: 1.3716 - accuracy: 0.4101 - val_loss: 1.0330 - val_accuracy: 0.5630
# Epoch 3/250
# 26/26 [==============================] - 0s 2ms/step - loss: 1.0770 - accuracy: 0.5024 - val_loss: 0.9432 - val_accuracy: 0.5472
# Epoch 4/250
# 26/26 [==============================] - 0s 2ms/step - loss: 0.9808 - accuracy: 0.5371 - val_loss: 0.9019 - val_accuracy: 0.5354
# Epoch 5/250
# 26/26 [==============================] - 0s 2ms/step - loss: 0.9219 - accuracy: 0.5242 - val_loss: 0.8536 - val_accuracy: 0.5591
# Epoch 6/250
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8411 - accuracy: 0.5457 - val_loss: 0.8581 - val_accuracy: 0.5984
# Epoch 7/250
# ...

# %%
# evaluate the model
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4955 - accuracy: 0.7682
# accuracy: 76.82%
